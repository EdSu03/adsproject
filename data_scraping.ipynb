# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os
from tqdm.notebook import tqdm
import io

import time
from urllib.parse import urljoin

# %%
# %pip install -r requirements.txt
# %pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
# Requirement already satisfied: fastparquet in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 1)) (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from fastparquet->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: numpy in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from fastparquet->-r requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: cramjam>=2.3 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from fastparquet->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: fsspec in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from fastparquet->-r requirements.txt (line 1)) (2024.2.0)
# Requirement already satisfied: packaging in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from fastparquet->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.5.0->fastparquet->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.5.0->fastparquet->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.5.0->fastparquet->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet->-r requirements.txt (line 1)) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyter_contrib_nbextensions in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (5.5.0)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (7.10.0)
# Requirement already satisfied: notebook>=6.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (7.0.6)
# Requirement already satisfied: tornado in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (6.3.3)
# Requirement already satisfied: traitlets>=4.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (5.13.0)
# Requirement already satisfied: lxml in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_nbextensions) (5.3.1)
# Requirement already satisfied: setuptools in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (68.2.2)
# Requirement already satisfied: jupyter-server in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.9.1)
# Requirement already satisfied: pyyaml in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.9.2)
# Requirement already satisfied: packaging in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.1)
# Requirement already satisfied: tinycss2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (306)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.25.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.0.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (8.5.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: overrides in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.18.0)
# Requirement already satisfied: pywinpty in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.12)
# Requirement already satisfied: pyzmq>=24 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (6.26.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.31.0)
# Requirement already satisfied: fastjsonschema in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.18.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.22)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (8.17.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.5.8)
# Requirement already satisfied: psutil in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.6)
# Requirement already satisfied: decorator in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.39)
# Requirement already satisfied: stack-data in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: colorama in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Requirement already satisfied: fqdn in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.4)
# Requirement already satisfied: uri-template in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.9)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\olive\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.8.19.14)
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_core\notebook_compat\nbextensions.py", line 6, in <module>
#     from notebook.extensions import BaseExtensionApp
# ModuleNotFoundError: No module named 'notebook.extensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_core\notebook_compat\nbextensions.py", line 10, in <module>
#     from notebook.nbextensions import BaseNBExtensionApp
# ModuleNotFoundError: No module named 'notebook.nbextensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\olive\AppData\Local\Programs\Python\Python312\Scripts\jupyter-contrib.EXE\__main__.py", line 7, in <module>
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_core\application.py", line 280, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\traitlets\config\application.py", line 1051, in launch_instance
#     app = cls.instance(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\traitlets\config\configurable.py", line 583, in instance
#     inst = cls(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_core\application.py", line 27, in __init__
#     self._refresh_subcommands()
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_core\application.py", line 43, in _refresh_subcommands
#     get_subcommands_dict = entrypoint.load()
#                            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pkg_resources\__init__.py", line 2518, in load
#     return self.resolve()
#            ^^^^^^^^^^^^^^
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\pkg_resources\__init__.py", line 2524, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_nbextensions\application.py", line 7, in <module>
#     from jupyter_contrib_core.notebook_compat.nbextensions import ArgumentConflict
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_core\notebook_compat\nbextensions.py", line 12, in <module>
#     from ._compat.nbextensions import BaseNBExtensionApp
#   File "c:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_contrib_core\notebook_compat\_compat\nbextensions.py", line 35, in <module>
#     from notebook.nbextensions import (
# ModuleNotFoundError: No module named 'notebook.nbextensions'
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# qtconsole run server troubleshoot
#
# Jupyter command `jupyter-nbextension` not found.
# (Deprecated) Installing extensions with the jupyter labextension install command is now deprecated and will be removed in a future major version of JupyterLab.
#
# Users should manage prebuilt extensions with package managers like pip and conda, and extension authors are encouraged to distribute their extensions as prebuilt packages
# C:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyterlab\debuglog.py:56: UserWarning: An error occurred.
#   warnings.warn("An error occurred.")
# C:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyterlab\debuglog.py:57: UserWarning: ValueError: Please install Node.js and npm before continuing installation. You may be able to install Node.js from your package manager, from conda, or directly from the Node.js website (https://nodejs.org).
#   warnings.warn(msg[-1].strip())
# C:\Users\olive\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyterlab\debuglog.py:58: UserWarning: See the log file for details: C:\Users\olive\AppData\Local\Temp\jupyterlab-debug-pn93q3g7.log
#   warnings.warn(f"See the log file for details: {log_path!s}")

# %%
## Get the data!

# Toggle whether to use the whole data or just a sample
USE_SAMPLE = True

# Scrape the given URL for all parquet file links
def get_parquets(url, taxi_type="yellow", years=[2024]):
    response = requests.get(url)
    if response.status_code != 200:
        return []
    
    soup = BeautifulSoup(response.text, "html.parser")
    return [
        a["href"].strip()
        for a in soup.find_all("a", href=True)
        if a["href"].strip().endswith(".parquet")
        and (not USE_SAMPLE or (taxi_type in a["href"] and any(str(year) in a["href"] for year in years)))
    ]

# Download a single file while displaying a progress bar
def download_and_optimize_parquet(url, save_path, position=1):
    response = requests.get(url, stream=True)
    total_size = int(response.headers.get('content-length', 0))

    raw_data = io.BytesIO()

    with tqdm(
        desc=os.path.basename(save_path),
        total=total_size,
        unit='B',
        unit_scale=True,
        unit_divisor=1024,
        position=position,
        leave=False,
        dynamic_ncols=True,
    ) as bar:
        for chunk in response.iter_content(chunk_size=1024):
            if chunk:
                raw_data.write(chunk)
                bar.update(len(chunk))

    raw_data.seek(0)

    # Optimise the DataFrame
    df = pd.read_parquet(raw_data, engine='fastparquet')

    for col in df.select_dtypes(include=['number']).columns:
        if pd.api.types.is_integer_dtype(df[col]):
            df[col] = pd.to_numeric(df[col], downcast='integer')
        elif pd.api.types.is_float_dtype(df[col]):
            df[col] = df[col].astype('float32')

    df.to_parquet(save_path, engine='fastparquet', index=False)

    return df


def download_and_read_parquet_files(url, save_dir="data", taxi_type="yellow", years=[2024]):
    os.makedirs(save_dir, exist_ok=True)

    links = get_parquets(url, taxi_type, years)
    dataframes = []

    with tqdm(total=len(links), desc="Processing files", unit="file", position=0, leave=True) as file_bar:
        for link in links:
            full_link = urljoin(url, link)
            filename = os.path.join(save_dir, os.path.basename(link))

            if not os.path.exists(filename):
                try:
                    df = download_and_optimize_parquet(full_link, filename, position=1)
                    dataframes.append(df)
                    file_bar.update(1)
                    time.sleep(5)
                    continue
                except Exception as e:
                    print(f"Error downloading/processing {filename}: {e}")
                    continue

            # Fallback if file exists already
            attempt = 0
            while attempt < 2:
                try:
                    df = pd.read_parquet(filename, engine='fastparquet')
                    dataframes.append(df)
                    break
                except Exception as e:
                    print(f"Error reading {filename}: {e}")
                    if attempt == 0:
                        os.remove(filename)
                        print("Redownloading...")
                        try:
                            df = download_and_optimize_parquet(full_link, filename, position=1)
                            dataframes.append(df)
                            break
                        except Exception as e2:
                            print(f"Retry failed: {e2}")
                    attempt += 1

            file_bar.update(1)

    return dataframes


url = "https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page"
dfs = download_and_read_parquet_files(url, taxi_type = "yellow", years=[2024, 2023])
# Out:
# Processing files:   0%|          | 0/24 [00:00<?, ?file/s]
